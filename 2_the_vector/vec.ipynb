# %%
# !cat vec.py
# Out:
# def setitem(v, k, val):
#     assert k in v.D
#     if val == 0: return
#     v.f[k] = val
#     return
#
# # We might want to use setDefault instead
# def getitem(v, k):
#     assert k in v.D
#
#     return v.f.get(k, 0)
# def equal(u,v):
#     assert u.D == v.D
#
#     return all( u[k] == v[k] for k in v.D)
# def add(u, v):
#     assert u.D == v.D
#     nV = Vec(u.D, {})
#     for d in u.D: nV[d] = u[d] + v[d]
#
#     return nV
#
#
# def dot(u, v):
#     assert u.D == v.D
#     cur_sum = 0
#     for d in u.D:
#         cur_sum += u[d] * v[d]
#
#     return cur_sum
# def scalar_mul(v, s):
#     nV = Vec(v.D, v.f.copy())
#
#     for k in nV.f.keys(): nV[k] = nV[k] * s
#
#     return nV
# def neg(v):
#     return scalar_mul(v, -1)
# ###############################################################################################################################
#
# class Vec:
#     """
#     A vector has two fields:
#     D - the domain (a set)
# ...

# %% [markdown]
# I want to update the necessary functions to make this work. What functions do I need to update?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Looking at `vec.py`, there are **7 functions** that need to be implemented (they all just have `pass` currently):
#
# 1. **`getitem(v, k)`** - return the value at key `k` (returning 0 if not in `v.f`)
# 2. **`setitem(v, k, val)`** - set the value at key `k`
# 3. **`equal(u, v)`** - check if two vectors are equal
# 4. **`add(u, v)`** - add two vectors
# 5. **`dot(u, v)`** - compute dot product
# 6. **`scalar_mul(v, alpha)`** - multiply vector by scalar
# 7. **`neg(v)`** - negate a vector
#
# I'd suggest starting with `getitem` and `setitem` first, since the other functions use bracket notation (`v[k]`) which relies on these working correctly.
#
# Which one would you like to tackle first?

# %% [markdown]
# Why does bracket notation rely on, and how getitem and setitem
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great question! Look at these lines in the `Vec` class:
#
# ```python
# __getitem__ = getitem
# __setitem__ = setitem
# ```
#
# In Python, when you write `v[k]`, Python automatically calls `v.__getitem__(k)`. Similarly, `v[k] = val` calls `v.__setitem__(k, val)`.
#
# So by assigning the functions `getitem` and `setitem` to these special "dunder" (double-underscore) methods, the `Vec` class gains bracket notation support.
#
# This is why implementing `getitem` first is important—once it works, you can use `u[k]` and `v[k]` in all the other functions (like `add`, `dot`, etc.) instead of having to deal with the sparse dictionary `v.f` directly.
#
# Want to try implementing `getitem`? The key insight is in the docstring: it should return 0 if `k` isn't in `v.f`.

# %% [markdown]
# dunder assignment is like operator overloading in c++?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Exactly right! It's Python's version of operator overloading.
#
# In C++ you might write:
# ```cpp
# T& operator[](int index) { ... }
# ```
#
# In Python, you define `__getitem__` instead. The syntax is different, but the concept is the same—you're telling the language what to do when someone uses `[]` on your object.
#
# Python has dunders for many operators: `__add__` for `+`, `__mul__` for `*`, `__eq__` for `==`, and so on. You can see several of these being used in the `Vec` class!

# %%
#| export
def setitem(v, k, val):
    assert k in v.D
    if val == 0: return
    v.f[k] = val
    return

# %%
#| export
# We might want to use setDefault instead
def getitem(v, k):
    assert k in v.D
    
    return v.f.get(k, 0)

# %%
#| export
def equal(u,v):
    assert u.D == v.D

    return all( u[k] == v[k] for k in v.D)

# %% [markdown]
# What might be the easiest wayt to check equality?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Since you've got `getitem` working, you can use bracket notation! The simplest approach: check that `u[k] == v[k]` for every `k` in the domain.
#
# What Python construct would you use to check a condition across all elements of a set?

# %% [markdown]
# No idea? maybe a map, reduce?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Those could work, but Python has something even simpler: the `all()` function!
#
# ```python
# all(condition for k in some_set)
# ```
#
# This returns `True` if the condition is true for every element, `False` otherwise.
#
# Can you use this pattern with `u[k] == v[k]` and `u.D`?

# %% [markdown]
# What other ways can this be done in languages like golang and ts?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠
#
# In **Go**, there's no built-in `all()`, so you'd typically use a loop:
# ```go
# for _, k := range domain {
#     if u[k] != v[k] { return false }
# }
# return true
# ```
#
# In **TypeScript**, you can use the `every()` method on arrays:
# ```typescript
# Array.from(domain).every(k => u[k] === v[k])
# ```
#
# Python's `all()` with a generator expression is quite elegant by comparison! Want to give it a try for `equal()`?

# %% [markdown]
# Whats the term (in programming / mathematics) when the order of arguments doesnt matter?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠
#
# The term is **commutative** (or **commutativity**).
#
# For example, addition is commutative because `a + b == b + a`. Same with multiplication. But subtraction and division are *not* commutative.
#
# In your `equal` function, you're relying on the fact that `==` is commutative—it doesn't matter whether you check `u[k] == v[k]` or `v[k] == u[k]`.

# %% [markdown]
# is this the same for a function?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Yes! A function is commutative if `f(a, b) == f(b, a)` for all inputs.
#
# For example:
# - `add(u, v)` should be commutative
# - `dot(u, v)` should be commutative
# - `equal(u, v)` should be commutative
#
# But `scalar_mul(v, alpha)` isn't really commutative in the sense that the arguments are different types—you can't swap a vector and a scalar.

# %%
#| export
def add(u, v):
    assert u.D == v.D
    nV = Vec(u.D, {})
    for d in u.D: nV[d] = u[d] + v[d]

    return nV

# %%
#| export
def dot(u, v):
    assert u.D == v.D
    cur_sum = 0
    for d in u.D: 
        cur_sum += u[d] * v[d]

    return cur_sum

# %%
#| export
def scalar_mul(v, s):
    nV = Vec(v.D, v.f.copy())

    for k in nV.f.keys(): nV[k] = nV[k] * s

    return nV

# %%
#| export
def neg(v):
    return scalar_mul(v, -1)

# %%
#| export
###############################################################################################################################

class Vec:
    """
    A vector has two fields:
    D - the domain (a set)
    f - a dictionary mapping (some) domain elements to field elements
        elements of D not appearing in f are implicitly mapped to zero
    """
    def __init__(self, labels, function):
        assert isinstance(labels, set)
        assert isinstance(function, dict)
        self.D = labels
        self.f = function

    __getitem__ = getitem
    __setitem__ = setitem
    __neg__ = neg
    __rmul__ = scalar_mul #if left arg of * is primitive, assume it's a scalar

    def __mul__(self,other):
        #If other is a vector, returns the dot product of self and other
        if isinstance(other, Vec):
            return dot(self,other)
        else:
            return NotImplemented  #  Will cause other.__rmul__(self) to be invoked

    def __truediv__(self,other):  # Scalar division
        return (1/other)*self

    __add__ = add

    def __radd__(self, other):
        "Hack to allow sum(...) to work with vectors"
        if other == 0:
            return self

    def __sub__(a,b):
        "Returns a vector which is the difference of a and b."
        return a+(-b)

    __eq__ = equal

    def is_almost_zero(self):
        s = 0
        for x in self.f.values():
            if isinstance(x, int) or isinstance(x, float):
                s += x*x
            elif isinstance(x, complex):
                y = abs(x)
                s += y*y
            else: return False
        return s < 1e-20

    def __str__(v):
        "pretty-printing"
        D_list = sorted(v.D, key=repr)
        numdec = 3
        wd = dict([(k,(1+max(len(str(k)), len('{0:.{1}G}'.format(v[k], numdec))))) if isinstance(v[k], int) or isinstance(v[k], float) else (k,(1+max(len(str(k)), len(str(v[k]))))) for k in D_list])
        s1 = ''.join(['{0:>{1}}'.format(str(k),wd[k]) for k in D_list])
        s2 = ''.join(['{0:>{1}.{2}G}'.format(v[k],wd[k],numdec) if isinstance(v[k], int) or isinstance(v[k], float) else '{0:>{1}}'.format(v[k], wd[k]) for k in D_list])
        return "\n" + s1 + "\n" + '-'*sum(wd.values()) +"\n" + s2

    def __hash__(self):
        "Here we pretend Vecs are immutable so we can form sets of them"
        h = hash(frozenset(self.D))
        for k,v in sorted(self.f.items(), key = lambda x:repr(x[0])):
            if v != 0:
                h = hash((h, hash(v)))
        return h

    def __repr__(self):
        return "Vec(" + str(self.D) + "," + str(self.f) + ")"

    def copy(self):
        "Don't make a new copy of the domain D"
        return Vec(self.D, self.f.copy())

    def __iter__(self):
        raise TypeError('%r object is not iterable' % self.__class__.__name__)

# %%
#| export
def zero_vec(D): return Vec(D, {}) # sparse representation

# %%
zero_vec({1, 2 ,3})
# Out:
# Vec({1, 2, 3},{})

# %% [markdown]
# for the dunder methods that don't define the order of arguments how do you know which arguments will be passed in? i.e I thought that rmul would first pass the scalar and then the vector.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great question! For `__rmul__`, when you write `3 * vec`:
#
# 1. Python first tries `(3).__mul__(vec)` — but `int` doesn't know how to handle a `Vec`, so it returns `NotImplemented`
# 2. Python then tries `vec.__rmul__(3)`
#
# So `self` (the vector) is always the **first** argument, and the scalar comes **second**.
#
# Looking at your `scalar_mul(s, v)` — the parameters are in the wrong order! When used as `__rmul__`, `s` will receive the vector and `v` will receive the scalar.
#
# Can you see how to fix it?

# %% [markdown]
# create test cases
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Here are some test cases to try:
#
# ```python
# # Setup
# D = {'a', 'b', 'c'}
# u = Vec(D, {'a': 1, 'b': 2, 'c': 3})
# v = Vec(D, {'a': 4, 'b': 5, 'c': 6})
#
# # Test getitem/setitem
# print("u['a'] =", u['a'])      # expect 1
# print("u['c'] =", u['c'])      # expect 3
#
# # Test equal
# w = Vec(D, {'a': 1, 'b': 2, 'c': 3})
# print("u == w:", u == w)       # expect True
# print("u == v:", u == v)       # expect False
#
# # Test add
# print("u + v:", u + v)         # expect a:5, b:7, c:9
#
# # Test dot product
# print("u * v:", u * v)         # expect scalar: 1*4 + 2*5 + 3*6 = 32
#
# # Test scalar multiplication
# print("2 * u:", 2 * u)         # expect a:2, b:4, c:6
#
# # Test negation
# print("-u:", -u)               # expect a:-1, b:-2, c:-3
# ```
#
# Run these and let me know what happens—I suspect you'll find a few bugs! 🐛

# %%
# Setup
D = {'a', 'b', 'c'}
u = Vec(D, {'a': 1, 'b': 2, 'c': 3})
v = Vec(D, {'a': 4, 'b': 5, 'c': 6})

# Test getitem/setitem
print("u['a'] =", u['a'])      # expect 1
print("u['c'] =", u['c'])      # expect 3

# Test equal
w = Vec(D, {'a': 1, 'b': 2, 'c': 3})
print("u == w:", u == w)       # expect True
print("u == v:", u == v)       # expect False

# Test add
print("u + v:", u + v)         # expect a:5, b:7, c:9

# Test dot product
print("u * v:", u * v)         # expect scalar: 1*4 + 2*5 + 3*6 = 32

# Test scalar multiplication
print("2 * u:", 2 * u)         # expect a:2, b:4, c:6

# Test negation
print("-u:", -u)               # expect a:-1, b:-2, c:-3
# Out:
# u['a'] = 1
# u['c'] = 3
# u == w: True
# u == v: False
# u + v:
#  a b c
# ------
#  5 7 9
# u * v: 32
# 2 * u:
#  a b c
# ------
#  2 4 6
# -u:
#   a  b  c
# ---------
#  -1 -2 -3

# %% [markdown]
# Any ways I could improve the code?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# All tests pass—nice work! A few suggestions:
#
# 1. **`setitem`**: The `v.f.setdefault(k,0)` line is redundant since you immediately overwrite with `v.f[k] = val` anyway.
#
# 2. **`neg`**: Could you reuse `scalar_mul` here instead of duplicating the loop logic?
#
# 3. **`scalar_mul`**: You're only iterating over keys in `v.f`, but what if the domain has elements not in `f`? (Hint: it works because `0 * s = 0`, but is it intentional?)
#
# Which one would you like to look at first?

# %% [markdown]
# If you try to set a key that doesn't exist, won't you get an error?
# Yes we can use scalar mul
# I'm only iterating over the exisiting keys because of it being a sparse representation.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Good points!
#
# 1. **`setitem`**: In Python, `v.f[k] = val` will create the key if it doesn't exist—dictionaries don't require keys to exist before assignment. So `setdefault` is still redundant there. Try it!
#
# 2. **`neg`**: Great! How would you rewrite it using `scalar_mul`?
#
# 3. **Sparse representation**: Exactly right—that's smart and intentional. 👍

# %% [markdown]
# When is setdefault useful? generally?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠
#
# `setdefault` is useful when you want to **get** a value but also **initialize** it if it doesn't exist—in a single operation.
#
# Classic example—building a dictionary of lists:
#
# ```python
# groups = {}
# groups.setdefault('fruit', []).append('apple')
# groups.setdefault('fruit', []).append('banana')
# # Result: {'fruit': ['apple', 'banana']}
# ```
#
# Without `setdefault`, you'd need:
# ```python
# if 'fruit' not in groups:
#     groups['fruit'] = []
# groups['fruit'].append('apple')
# ```
#
# So it's handy when you're **accumulating** values, not just assigning them.
